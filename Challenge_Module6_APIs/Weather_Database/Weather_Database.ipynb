# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(-90.000, 90.000, size=2000)
lngs = np.random.uniform(-180.000, 180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
# coordinates

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 782

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
#url

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Begining of Data Retrivel")
print("-------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # print(city_weather)
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        # city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Begining of Data Retrivel
# -------------------------
# Processing Record 1 of Set 1 | busselton
# Processing Record 2 of Set 1 | bambous virieux
# Processing Record 3 of Set 1 | port elizabeth
# Processing Record 4 of Set 1 | hilo
# Processing Record 5 of Set 1 | barcelos
# Processing Record 6 of Set 1 | kamenka
# Processing Record 7 of Set 1 | maneadero
# Processing Record 8 of Set 1 | wichita falls
# Processing Record 9 of Set 1 | jilove
# Processing Record 10 of Set 1 | christchurch
# Processing Record 11 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 1 | tuktoyaktuk
# Processing Record 13 of Set 1 | lasa
# Processing Record 14 of Set 1 | richards bay
# Processing Record 15 of Set 1 | barrow
# Processing Record 16 of Set 1 | georgetown
# Processing Record 17 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 18 of Set 1 | mount gambier
# Processing Record 19 of Set 1 | cherskiy
# Processing Record 20 of Set 1 | saint-philippe
# Processing Record 21 of Set 1 | jamestown
# Processing Record 22 of Set 1 | jibuti
# Processing Record 23 of Set 1 | mataura
# Processing Record 24 of Set 1 | hermanus
# Processing Record 25 of Set 1 | vaini
# Processing Record 26 of Set 1 | cururupu
# Processing Record 27 of Set 1 | ilulissat
# Processing Record 28 of Set 1 | albany
# Processing Record 29 of Set 1 | aklavik
# Processing Record 30 of Set 1 | atuona
# Processing Record 31 of Set 1 | sao filipe
# Processing Record 32 of Set 1 | starobesheve
# Processing Record 33 of Set 1 | kalmunai
# Processing Record 34 of Set 1 | norman wells
# Processing Record 35 of Set 1 | bathsheba
# Processing Record 36 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 37 of Set 1 | port alfred
# Processing Record 38 of Set 1 | saskylakh
# Processing Record 39 of Set 1 | sortavala
# Processing Record 40 of Set 1 | rikitea
# Processing Record 41 of Set 1 | ushuaia
# Processing Record 42 of Set 1 | longyearbyen
# Processing Record 43 of Set 1 | alpena
# Processing Record 44 of Set 1 | honiara
# Processing Record 45 of Set 1 | bengkulu
# Processing Record 46 of Set 1 | yarada
# Processing Record 47 of Set 1 | zbarazh
# Processing Record 48 of Set 1 | svetlyy
# Processing Record 49 of Set 1 | senanga
# Processing Record 50 of Set 1 | kavieng
# Processing Record 1 of Set 2 | tasiilaq
# Processing Record 2 of Set 2 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 3 of Set 2 | caravelas
# Processing Record 4 of Set 2 | port lincoln
# Processing Record 5 of Set 2 | provideniya
# Processing Record 6 of Set 2 | listvyanskiy
# Processing Record 7 of Set 2 | halalo
# City not found. Skipping...
# Processing Record 8 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 9 of Set 2 | kodiak
# Processing Record 10 of Set 2 | pevek
# Processing Record 11 of Set 2 | kapaa
# Processing Record 12 of Set 2 | qaanaaq
# Processing Record 13 of Set 2 | punta arenas
# Processing Record 14 of Set 2 | avarua
# Processing Record 15 of Set 2 | luanda
# Processing Record 16 of Set 2 | leningradskiy
# Processing Record 17 of Set 2 | muros
# Processing Record 18 of Set 2 | nizwa
# Processing Record 19 of Set 2 | severo-kurilsk
# Processing Record 20 of Set 2 | tiksi
# Processing Record 21 of Set 2 | gainesville
# Processing Record 22 of Set 2 | pitimbu
# Processing Record 23 of Set 2 | castro
# Processing Record 24 of Set 2 | am timan
# Processing Record 25 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 26 of Set 2 | fairbanks
# Processing Record 27 of Set 2 | hobart
# Processing Record 28 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 29 of Set 2 | cayenne
# Processing Record 30 of Set 2 | marsassoum
# Processing Record 31 of Set 2 | faanui
# Processing Record 32 of Set 2 | lebu
# Processing Record 33 of Set 2 | puerto penasco
# Processing Record 34 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 35 of Set 2 | srednekolymsk
# Processing Record 36 of Set 2 | hithadhoo
# Processing Record 37 of Set 2 | rocha
# Processing Record 38 of Set 2 | dawei
# Processing Record 39 of Set 2 | tessalit
# Processing Record 40 of Set 2 | bluff
# Processing Record 41 of Set 2 | saldanha
# Processing Record 42 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 43 of Set 2 | urozhaynoye
# Processing Record 44 of Set 2 | flinders
# Processing Record 45 of Set 2 | oskarshamn
# Processing Record 46 of Set 2 | timmins
# Processing Record 47 of Set 2 | bousso
# Processing Record 48 of Set 2 | zhaozhou
# Processing Record 49 of Set 2 | anori
# Processing Record 50 of Set 2 | mocambique
# City not found. Skipping...
# Processing Record 1 of Set 3 | khatanga
# Processing Record 2 of Set 3 | bredasdorp
# Processing Record 3 of Set 3 | dikson
# Processing Record 4 of Set 3 | kannapolis
# Processing Record 5 of Set 3 | geraldton
# Processing Record 6 of Set 3 | joao pinheiro
# Processing Record 7 of Set 3 | oranjemund
# Processing Record 8 of Set 3 | cassilandia
# Processing Record 9 of Set 3 | port blair
# Processing Record 10 of Set 3 | mnogovershinnyy
# Processing Record 11 of Set 3 | tamandare
# Processing Record 12 of Set 3 | nikolskoye
# Processing Record 13 of Set 3 | baia de aries
# Processing Record 14 of Set 3 | tawnat
# City not found. Skipping...
# Processing Record 15 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 16 of Set 3 | eyl
# Processing Record 17 of Set 3 | bireun
# Processing Record 18 of Set 3 | corn island
# Processing Record 19 of Set 3 | gat
# Processing Record 20 of Set 3 | champasak
# Processing Record 21 of Set 3 | kahului
# Processing Record 22 of Set 3 | camacha
# Processing Record 23 of Set 3 | mikkeli
# Processing Record 24 of Set 3 | agadez
# Processing Record 25 of Set 3 | rosamorada
# Processing Record 26 of Set 3 | phan rang
# City not found. Skipping...
# Processing Record 27 of Set 3 | namatanai
# Processing Record 28 of Set 3 | san patricio
# Processing Record 29 of Set 3 | bud
# Processing Record 30 of Set 3 | lompoc
# Processing Record 31 of Set 3 | cherepanovo
# Processing Record 32 of Set 3 | yellowknife
# Processing Record 33 of Set 3 | erdenet
# Processing Record 34 of Set 3 | sipe sipe
# Processing Record 35 of Set 3 | auki
# Processing Record 36 of Set 3 | katherine
# Processing Record 37 of Set 3 | senador guiomard
# Processing Record 38 of Set 3 | yulara
# Processing Record 39 of Set 3 | chokurdakh
# Processing Record 40 of Set 3 | cape town
# Processing Record 41 of Set 3 | kaitangata
# Processing Record 42 of Set 3 | college
# Processing Record 43 of Set 3 | coahuayana
# Processing Record 44 of Set 3 | butaritari
# Processing Record 45 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 47 of Set 3 | maceio
# Processing Record 48 of Set 3 | phan thiet
# Processing Record 49 of Set 3 | arraial do cabo
# Processing Record 50 of Set 3 | westport
# Processing Record 1 of Set 4 | zelenogorskiy
# Processing Record 2 of Set 4 | porto novo
# Processing Record 3 of Set 4 | maua
# Processing Record 4 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 4 | mar del plata
# Processing Record 6 of Set 4 | dolores
# Processing Record 7 of Set 4 | antalaha
# Processing Record 8 of Set 4 | tabou
# Processing Record 9 of Set 4 | vostok
# Processing Record 10 of Set 4 | lugo
# Processing Record 11 of Set 4 | okato
# Processing Record 12 of Set 4 | belmonte
# Processing Record 13 of Set 4 | lavrentiya
# Processing Record 14 of Set 4 | lagoa
# Processing Record 15 of Set 4 | markala
# Processing Record 16 of Set 4 | kanniyakumari
# Processing Record 17 of Set 4 | jutai
# Processing Record 18 of Set 4 | torbay
# Processing Record 19 of Set 4 | krasnovishersk
# Processing Record 20 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 21 of Set 4 | kuldur
# Processing Record 22 of Set 4 | tupiza
# Processing Record 23 of Set 4 | duminichi
# Processing Record 24 of Set 4 | taoudenni
# Processing Record 25 of Set 4 | hendijan
# City not found. Skipping...
# Processing Record 26 of Set 4 | bethel
# Processing Record 27 of Set 4 | melfi
# Processing Record 28 of Set 4 | necochea
# Processing Record 29 of Set 4 | chase
# Processing Record 30 of Set 4 | new norfolk
# Processing Record 31 of Set 4 | sangar
# Processing Record 32 of Set 4 | haines junction
# Processing Record 33 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 34 of Set 4 | plyussa
# Processing Record 35 of Set 4 | norrtalje
# Processing Record 36 of Set 4 | praia
# Processing Record 37 of Set 4 | unye
# City not found. Skipping...
# Processing Record 38 of Set 4 | skibbereen
# Processing Record 39 of Set 4 | hailey
# Processing Record 40 of Set 4 | great yarmouth
# Processing Record 41 of Set 4 | pringsewu
# Processing Record 42 of Set 4 | liepaja
# Processing Record 43 of Set 4 | terney
# Processing Record 44 of Set 4 | xining
# Processing Record 45 of Set 4 | vestmannaeyjar
# Processing Record 46 of Set 4 | coquimbo
# Processing Record 47 of Set 4 | narsaq
# Processing Record 48 of Set 4 | garowe
# Processing Record 49 of Set 4 | balclutha
# Processing Record 50 of Set 4 | glubokoe
# City not found. Skipping...
# Processing Record 1 of Set 5 | kailua
# Processing Record 2 of Set 5 | zhangye
# Processing Record 3 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 4 of Set 5 | maumere
# Processing Record 5 of Set 5 | whitehorse
# Processing Record 6 of Set 5 | itigi
# Processing Record 7 of Set 5 | vila
# Processing Record 8 of Set 5 | prince rupert
# Processing Record 9 of Set 5 | san quintin
# Processing Record 10 of Set 5 | marion
# Processing Record 11 of Set 5 | kozhva
# Processing Record 12 of Set 5 | conceicao do araguaia
# Processing Record 13 of Set 5 | sioux lookout
# Processing Record 14 of Set 5 | oktyabrskiy
# Processing Record 15 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 16 of Set 5 | elbeuf
# Processing Record 17 of Set 5 | murayama
# Processing Record 18 of Set 5 | ribeira grande
# Processing Record 19 of Set 5 | nemuro
# Processing Record 20 of Set 5 | oyama
# Processing Record 21 of Set 5 | olinda
# Processing Record 22 of Set 5 | kuryk
# Processing Record 23 of Set 5 | plettenberg bay
# Processing Record 24 of Set 5 | ixtapa
# Processing Record 25 of Set 5 | atambua
# Processing Record 26 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 27 of Set 5 | san jeronimo
# Processing Record 28 of Set 5 | thompson
# Processing Record 29 of Set 5 | zhigansk
# Processing Record 30 of Set 5 | beloha
# Processing Record 31 of Set 5 | piney green
# Processing Record 32 of Set 5 | moose factory
# Processing Record 33 of Set 5 | asyut
# Processing Record 34 of Set 5 | te anau
# Processing Record 35 of Set 5 | alyangula
# Processing Record 36 of Set 5 | brigantine
# Processing Record 37 of Set 5 | ancud
# Processing Record 38 of Set 5 | pangody
# Processing Record 39 of Set 5 | antequera
# Processing Record 40 of Set 5 | nome
# Processing Record 41 of Set 5 | nelson bay
# Processing Record 42 of Set 5 | quibdo
# Processing Record 43 of Set 5 | cidreira
# Processing Record 44 of Set 5 | clyde river
# Processing Record 45 of Set 5 | east london
# Processing Record 46 of Set 5 | yuzhou
# Processing Record 47 of Set 5 | anchorage
# Processing Record 48 of Set 5 | lakes entrance
# Processing Record 49 of Set 5 | sao felix do xingu
# Processing Record 50 of Set 5 | yerbogachen
# Processing Record 1 of Set 6 | valparaiso
# Processing Record 2 of Set 6 | sept-iles
# Processing Record 3 of Set 6 | mettur
# Processing Record 4 of Set 6 | iqaluit
# Processing Record 5 of Set 6 | nanortalik
# Processing Record 6 of Set 6 | tuatapere
# Processing Record 7 of Set 6 | passo de camaragibe
# Processing Record 8 of Set 6 | tyret pervaya
# Processing Record 9 of Set 6 | pinotepa nacional
# Processing Record 10 of Set 6 | capitao poco
# Processing Record 11 of Set 6 | carnarvon
# Processing Record 12 of Set 6 | roald
# Processing Record 13 of Set 6 | freeport
# Processing Record 14 of Set 6 | tatawin
# Processing Record 15 of Set 6 | bafra
# Processing Record 16 of Set 6 | vavuniya
# Processing Record 17 of Set 6 | northam
# Processing Record 18 of Set 6 | katsuura
# Processing Record 19 of Set 6 | quatre cocos
# Processing Record 20 of Set 6 | constitucion
# Processing Record 21 of Set 6 | kloulklubed
# Processing Record 22 of Set 6 | mareeba
# Processing Record 23 of Set 6 | sault sainte marie
# Processing Record 24 of Set 6 | lidzbark warminski
# Processing Record 25 of Set 6 | cabo san lucas
# Processing Record 26 of Set 6 | ahumada
# City not found. Skipping...
# Processing Record 27 of Set 6 | mahebourg
# Processing Record 28 of Set 6 | mahajanga
# Processing Record 29 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 30 of Set 6 | codrington
# Processing Record 31 of Set 6 | atar
# Processing Record 32 of Set 6 | bealanana
# Processing Record 33 of Set 6 | monrovia
# Processing Record 34 of Set 6 | buala
# Processing Record 35 of Set 6 | beisfjord
# Processing Record 36 of Set 6 | saint-louis
# Processing Record 37 of Set 6 | siniscola
# Processing Record 38 of Set 6 | kologriv
# Processing Record 39 of Set 6 | rio de janeiro
# Processing Record 40 of Set 6 | ischia
# Processing Record 41 of Set 6 | fuerte olimpo
# Processing Record 42 of Set 6 | klaksvik
# Processing Record 43 of Set 6 | jiaonan
# Processing Record 44 of Set 6 | charters towers
# Processing Record 45 of Set 6 | labytnangi
# Processing Record 46 of Set 6 | ilhabela
# Processing Record 47 of Set 6 | luderitz
# Processing Record 48 of Set 6 | nara
# Processing Record 49 of Set 6 | mahibadhoo
# Processing Record 50 of Set 6 | zelenoborsk
# Processing Record 1 of Set 7 | grand centre
# City not found. Skipping...
# Processing Record 2 of Set 7 | dalvik
# Processing Record 3 of Set 7 | puerto ayora
# Processing Record 4 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 5 of Set 7 | chuy
# Processing Record 6 of Set 7 | salalah
# Processing Record 7 of Set 7 | cukai
# Processing Record 8 of Set 7 | nichinan
# Processing Record 9 of Set 7 | camiri
# Processing Record 10 of Set 7 | nuuk
# Processing Record 11 of Set 7 | povenets
# Processing Record 12 of Set 7 | bereda
# Processing Record 13 of Set 7 | coihaique
# Processing Record 14 of Set 7 | along
# Processing Record 15 of Set 7 | makat
# Processing Record 16 of Set 7 | bibiani
# Processing Record 17 of Set 7 | hokitika
# Processing Record 18 of Set 7 | sassandra
# Processing Record 19 of Set 7 | abu samrah
# Processing Record 20 of Set 7 | rayagada
# Processing Record 21 of Set 7 | nynashamn
# Processing Record 22 of Set 7 | la ronge
# Processing Record 23 of Set 7 | arlit
# Processing Record 24 of Set 7 | uruacu
# Processing Record 25 of Set 7 | pangnirtung
# Processing Record 26 of Set 7 | mokhsogollokh
# Processing Record 27 of Set 7 | behshahr
# Processing Record 28 of Set 7 | san cristobal
# Processing Record 29 of Set 7 | bad sachsa
# Processing Record 30 of Set 7 | kamaishi
# Processing Record 31 of Set 7 | abha
# Processing Record 32 of Set 7 | sambava
# Processing Record 33 of Set 7 | kaeo
# Processing Record 34 of Set 7 | marv dasht
# City not found. Skipping...
# Processing Record 35 of Set 7 | bilibino
# Processing Record 36 of Set 7 | potsdam
# Processing Record 37 of Set 7 | namibe
# Processing Record 38 of Set 7 | padang
# Processing Record 39 of Set 7 | sungaipenuh
# Processing Record 40 of Set 7 | santa cruz
# Processing Record 41 of Set 7 | praia da vitoria
# Processing Record 42 of Set 7 | oussouye
# Processing Record 43 of Set 7 | riyadh
# Processing Record 44 of Set 7 | chilca
# Processing Record 45 of Set 7 | khorixas
# Processing Record 46 of Set 7 | pangoa
# Processing Record 47 of Set 7 | filingue
# Processing Record 48 of Set 7 | poum
# Processing Record 49 of Set 7 | lira
# Processing Record 50 of Set 7 | nguiu
# City not found. Skipping...
# Processing Record 1 of Set 8 | bandarbeyla
# Processing Record 2 of Set 8 | angoche
# Processing Record 3 of Set 8 | laje
# Processing Record 4 of Set 8 | port hedland
# Processing Record 5 of Set 8 | catamarca
# Processing Record 6 of Set 8 | mehamn
# Processing Record 7 of Set 8 | abu zabad
# Processing Record 8 of Set 8 | waipawa
# Processing Record 9 of Set 8 | tuy hoa
# Processing Record 10 of Set 8 | gizo
# Processing Record 11 of Set 8 | hambantota
# Processing Record 12 of Set 8 | sakakah
# Processing Record 13 of Set 8 | birao
# Processing Record 14 of Set 8 | sulphur springs
# Processing Record 15 of Set 8 | kristinehamn
# Processing Record 16 of Set 8 | seymchan
# Processing Record 17 of Set 8 | ahipara
# Processing Record 18 of Set 8 | airai
# Processing Record 19 of Set 8 | howard springs
# Processing Record 20 of Set 8 | iaciara
# Processing Record 21 of Set 8 | burns lake
# Processing Record 22 of Set 8 | shunyi
# Processing Record 23 of Set 8 | kano
# Processing Record 24 of Set 8 | soyo
# Processing Record 25 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 26 of Set 8 | inderborskiy
# City not found. Skipping...
# Processing Record 27 of Set 8 | nushki
# Processing Record 28 of Set 8 | acapulco
# Processing Record 29 of Set 8 | slave lake
# Processing Record 30 of Set 8 | duldurga
# Processing Record 31 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 32 of Set 8 | linqiong
# Processing Record 33 of Set 8 | joniskelis
# Processing Record 34 of Set 8 | phalaborwa
# Processing Record 35 of Set 8 | saint-joseph
# Processing Record 36 of Set 8 | korla
# Processing Record 37 of Set 8 | gondar
# Processing Record 38 of Set 8 | vila velha
# Processing Record 39 of Set 8 | victoria
# Processing Record 40 of Set 8 | borlange
# City not found. Skipping...
# Processing Record 41 of Set 8 | juneau
# Processing Record 42 of Set 8 | trairi
# Processing Record 43 of Set 8 | esperance
# Processing Record 44 of Set 8 | saint anthony
# Processing Record 45 of Set 8 | korem
# Processing Record 46 of Set 8 | padre bernardo
# Processing Record 47 of Set 8 | dunedin
# Processing Record 48 of Set 8 | cayhagan
# Processing Record 49 of Set 8 | saint george
# Processing Record 50 of Set 8 | jhanjharpur
# Processing Record 1 of Set 9 | goderich
# Processing Record 2 of Set 9 | manta
# Processing Record 3 of Set 9 | leo
# Processing Record 4 of Set 9 | batemans bay
# Processing Record 5 of Set 9 | shenjiamen
# Processing Record 6 of Set 9 | bacolod
# Processing Record 7 of Set 9 | chapais
# Processing Record 8 of Set 9 | kendari
# Processing Record 9 of Set 9 | emerald
# Processing Record 10 of Set 9 | marsh harbour
# Processing Record 11 of Set 9 | tome-acu
# City not found. Skipping...
# Processing Record 12 of Set 9 | porto velho
# Processing Record 13 of Set 9 | harper
# Processing Record 14 of Set 9 | orcopampa
# Processing Record 15 of Set 9 | san carlos de bariloche
# Processing Record 16 of Set 9 | ponta do sol
# Processing Record 17 of Set 9 | puri
# Processing Record 18 of Set 9 | marawi
# Processing Record 19 of Set 9 | gweta
# Processing Record 20 of Set 9 | skalistyy
# City not found. Skipping...
# Processing Record 21 of Set 9 | virginia beach
# Processing Record 22 of Set 9 | broome
# Processing Record 23 of Set 9 | avera
# Processing Record 24 of Set 9 | alice springs
# Processing Record 25 of Set 9 | gorom-gorom
# Processing Record 26 of Set 9 | vao
# Processing Record 27 of Set 9 | shiyan
# Processing Record 28 of Set 9 | tevaitoa
# Processing Record 29 of Set 9 | rio hato
# Processing Record 30 of Set 9 | cascais
# Processing Record 31 of Set 9 | galiwinku
# City not found. Skipping...
# Processing Record 32 of Set 9 | nikolayevsk-na-amure
# Processing Record 33 of Set 9 | jacareacanga
# Processing Record 34 of Set 9 | kalur kot
# Processing Record 35 of Set 9 | igarka
# Processing Record 36 of Set 9 | allapalli
# Processing Record 37 of Set 9 | poso
# Processing Record 38 of Set 9 | navoi
# Processing Record 39 of Set 9 | green river
# Processing Record 40 of Set 9 | morondava
# Processing Record 41 of Set 9 | piritiba
# Processing Record 42 of Set 9 | ola
# Processing Record 43 of Set 9 | samsun
# Processing Record 44 of Set 9 | besikduzu
# Processing Record 45 of Set 9 | barbar
# City not found. Skipping...
# Processing Record 46 of Set 9 | killybegs
# Processing Record 47 of Set 9 | vanimo
# Processing Record 48 of Set 9 | ocean city
# Processing Record 49 of Set 9 | mayo
# Processing Record 50 of Set 9 | alofi
# Processing Record 1 of Set 10 | umm kaddadah
# Processing Record 2 of Set 10 | fortuna
# Processing Record 3 of Set 10 | ingham
# Processing Record 4 of Set 10 | kuusamo
# Processing Record 5 of Set 10 | kropotkin
# Processing Record 6 of Set 10 | iskateley
# Processing Record 7 of Set 10 | havre-saint-pierre
# Processing Record 8 of Set 10 | nalut
# Processing Record 9 of Set 10 | koudougou
# Processing Record 10 of Set 10 | yeniseysk
# Processing Record 11 of Set 10 | rabaul
# Processing Record 12 of Set 10 | moba
# Processing Record 13 of Set 10 | maloy
# Processing Record 14 of Set 10 | road town
# Processing Record 15 of Set 10 | hasaki
# Processing Record 16 of Set 10 | axim
# Processing Record 17 of Set 10 | marzuq
# Processing Record 18 of Set 10 | chara
# Processing Record 19 of Set 10 | ostersund
# Processing Record 20 of Set 10 | matane
# Processing Record 21 of Set 10 | teya
# Processing Record 22 of Set 10 | sinjah
# City not found. Skipping...
# Processing Record 23 of Set 10 | zhanakorgan
# Processing Record 24 of Set 10 | grakhovo
# Processing Record 25 of Set 10 | fenoarivo
# Processing Record 26 of Set 10 | tromso
# Processing Record 27 of Set 10 | bosansko grahovo
# Processing Record 28 of Set 10 | les cayes
# Processing Record 29 of Set 10 | kavaratti
# Processing Record 30 of Set 10 | colesberg
# Processing Record 31 of Set 10 | sosnovo
# Processing Record 32 of Set 10 | muzhi
# Processing Record 33 of Set 10 | sfantu gheorghe
# Processing Record 34 of Set 10 | shellbrook
# Processing Record 35 of Set 10 | puerto escondido
# Processing Record 36 of Set 10 | jalu
# Processing Record 37 of Set 10 | hammerfest
# Processing Record 38 of Set 10 | lorengau
# Processing Record 39 of Set 10 | cabras
# Processing Record 40 of Set 10 | kenitra
# Processing Record 41 of Set 10 | kununurra
# Processing Record 42 of Set 10 | bairiki
# Processing Record 43 of Set 10 | samarai
# Processing Record 44 of Set 10 | bogovina
# Processing Record 45 of Set 10 | taltal
# Processing Record 46 of Set 10 | ust-maya
# Processing Record 47 of Set 10 | san pedro
# Processing Record 48 of Set 10 | savannah bight
# Processing Record 49 of Set 10 | ambon
# Processing Record 50 of Set 10 | kembe
# Processing Record 1 of Set 11 | walvis bay
# Processing Record 2 of Set 11 | tsabong
# Processing Record 3 of Set 11 | urengoy
# Processing Record 4 of Set 11 | hun
# Processing Record 5 of Set 11 | grindavik
# Processing Record 6 of Set 11 | ngunguru
# Processing Record 7 of Set 11 | biak
# Processing Record 8 of Set 11 | iquique
# Processing Record 9 of Set 11 | amazar
# Processing Record 10 of Set 11 | potchefstroom
# Processing Record 11 of Set 11 | dongsheng
# Processing Record 12 of Set 11 | opuwo
# Processing Record 13 of Set 11 | upernavik
# Processing Record 14 of Set 11 | teneguiban
# City not found. Skipping...
# Processing Record 15 of Set 11 | stephenville
# Processing Record 16 of Set 11 | pafos
# Processing Record 17 of Set 11 | mirador
# Processing Record 18 of Set 11 | port hardy
# Processing Record 19 of Set 11 | okha
# Processing Record 20 of Set 11 | anderson
# Processing Record 21 of Set 11 | penzance
# Processing Record 22 of Set 11 | yumen
# Processing Record 23 of Set 11 | sao joao da barra
# Processing Record 24 of Set 11 | arnprior
# Processing Record 25 of Set 11 | barranco de loba
# Processing Record 26 of Set 11 | nachalovo
# Processing Record 27 of Set 11 | labutta
# City not found. Skipping...
# Processing Record 28 of Set 11 | nabire
# Processing Record 29 of Set 11 | xiangdong
# City not found. Skipping...
# Processing Record 30 of Set 11 | esmeraldas
# Processing Record 31 of Set 11 | manacapuru
# Processing Record 32 of Set 11 | pierre
# Processing Record 33 of Set 11 | kapit
# Processing Record 34 of Set 11 | ust-nera
# Processing Record 35 of Set 11 | ostrovnoy
# Processing Record 36 of Set 11 | epinal
# Processing Record 37 of Set 11 | mawlaik
# Processing Record 38 of Set 11 | sovetskiy
# Processing Record 39 of Set 11 | santa rosalia
# Processing Record 40 of Set 11 | boyolangu
# Processing Record 41 of Set 11 | lata
# Processing Record 42 of Set 11 | kamen-rybolov
# Processing Record 43 of Set 11 | roma
# Processing Record 44 of Set 11 | pontian kecil
# Processing Record 45 of Set 11 | paita
# Processing Record 46 of Set 11 | bilma
# Processing Record 47 of Set 11 | manono
# Processing Record 48 of Set 11 | sinnamary
# Processing Record 49 of Set 11 | eydhafushi
# Processing Record 50 of Set 11 | lima
# Processing Record 1 of Set 12 | shangrao
# Processing Record 2 of Set 12 | aripuana
# Processing Record 3 of Set 12 | olafsvik
# Processing Record 4 of Set 12 | tazovskiy
# Processing Record 5 of Set 12 | nyimba
# Processing Record 6 of Set 12 | lichinga
# Processing Record 7 of Set 12 | masumbwe
# Processing Record 8 of Set 12 | komsomolskiy
# Processing Record 9 of Set 12 | ajaccio
# Processing Record 10 of Set 12 | fukue
# Processing Record 11 of Set 12 | moose jaw
# Processing Record 12 of Set 12 | san policarpo
# Processing Record 13 of Set 12 | gari
# Processing Record 14 of Set 12 | warrnambool
# Processing Record 15 of Set 12 | benguela
# Processing Record 16 of Set 12 | rawson
# Processing Record 17 of Set 12 | porosozero
# Processing Record 18 of Set 12 | baghdad
# Processing Record 19 of Set 12 | qostanay
# Processing Record 20 of Set 12 | tongchuan
# Processing Record 21 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 22 of Set 12 | arandis
# Processing Record 23 of Set 12 | hwange
# Processing Record 24 of Set 12 | labrea
# Processing Record 25 of Set 12 | aksarka
# Processing Record 26 of Set 12 | chulman
# Processing Record 27 of Set 12 | mathathane
# Processing Record 28 of Set 12 | azul
# Processing Record 29 of Set 12 | dudinka
# Processing Record 30 of Set 12 | longyan
# Processing Record 31 of Set 12 | bronnoysund
# Processing Record 32 of Set 12 | pontianak
# Processing Record 33 of Set 12 | okakarara
# Processing Record 34 of Set 12 | araguaina
# Processing Record 35 of Set 12 | kholm-zhirkovskiy
# Processing Record 36 of Set 12 | leeuwarden
# Processing Record 37 of Set 12 | zheleznodorozhnyy
# Processing Record 38 of Set 12 | vallenar
# Processing Record 39 of Set 12 | kruisfontein
# Processing Record 40 of Set 12 | cabinda
# Processing Record 41 of Set 12 | pocone
# Processing Record 42 of Set 12 | vernon
# Processing Record 43 of Set 12 | sitka
# Processing Record 44 of Set 12 | zhovti vody
# Processing Record 45 of Set 12 | talcahuano
# Processing Record 46 of Set 12 | xinzhou
# Processing Record 47 of Set 12 | kathu
# Processing Record 48 of Set 12 | istra
# Processing Record 49 of Set 12 | tari
# Processing Record 50 of Set 12 | high level
# Processing Record 1 of Set 13 | luau
# Processing Record 2 of Set 13 | wanaka
# Processing Record 3 of Set 13 | abbeville
# Processing Record 4 of Set 13 | si satchanalai
# Processing Record 5 of Set 13 | malwan
# City not found. Skipping...
# Processing Record 6 of Set 13 | cockburn town
# Processing Record 7 of Set 13 | husavik
# Processing Record 8 of Set 13 | pussi
# Processing Record 9 of Set 13 | sorland
# Processing Record 10 of Set 13 | bintulu
# Processing Record 11 of Set 13 | zolotinka
# City not found. Skipping...
# Processing Record 12 of Set 13 | tieling
# Processing Record 13 of Set 13 | tawkar
# City not found. Skipping...
# Processing Record 14 of Set 13 | ewa beach
# Processing Record 15 of Set 13 | ishigaki
# Processing Record 16 of Set 13 | aguimes
# Processing Record 17 of Set 13 | nkowakowa
# Processing Record 18 of Set 13 | pouembout
# Processing Record 19 of Set 13 | ketchikan
# Processing Record 20 of Set 13 | bojnurd
# Processing Record 21 of Set 13 | pizarro
# Processing Record 22 of Set 13 | dehloran
# Processing Record 23 of Set 13 | ruteng
# Processing Record 24 of Set 13 | grande-riviere
# City not found. Skipping...
# Processing Record 25 of Set 13 | shirokiy
# Processing Record 26 of Set 13 | kangaatsiaq
# Processing Record 27 of Set 13 | bengkalis
# City not found. Skipping...
# Processing Record 28 of Set 13 | beringovskiy
# Processing Record 29 of Set 13 | tateyama
# Processing Record 30 of Set 13 | syava
# Processing Record 31 of Set 13 | bischheim
# Processing Record 32 of Set 13 | chestermere
# Processing Record 33 of Set 13 | police
# Processing Record 34 of Set 13 | bafq
# Processing Record 35 of Set 13 | bababe
# City not found. Skipping...
# Processing Record 36 of Set 13 | plerin
# Processing Record 37 of Set 13 | ocampo
# Processing Record 38 of Set 13 | vilhena
# Processing Record 39 of Set 13 | sechura
# Processing Record 40 of Set 13 | palora
# Processing Record 41 of Set 13 | bern
# Processing Record 42 of Set 13 | lazaro cardenas
# Processing Record 43 of Set 13 | gamba
# Processing Record 44 of Set 13 | jaciara
# Processing Record 45 of Set 13 | hobyo
# Processing Record 46 of Set 13 | strezhevoy
# Processing Record 47 of Set 13 | nova olinda do norte
# Processing Record 48 of Set 13 | velikie luki
# City not found. Skipping...
# Processing Record 49 of Set 13 | ponta delgada
# Processing Record 50 of Set 13 | lisakovsk
# Processing Record 1 of Set 14 | solnechnyy
# Processing Record 2 of Set 14 | comodoro rivadavia
# Processing Record 3 of Set 14 | garoua
# Processing Record 4 of Set 14 | temba
# Processing Record 5 of Set 14 | aksehir
# Processing Record 6 of Set 14 | castelo
# Processing Record 7 of Set 14 | kingston
# Processing Record 8 of Set 14 | half moon bay
# Processing Record 9 of Set 14 | humacao
# Processing Record 10 of Set 14 | vagur
# Processing Record 11 of Set 14 | buraydah
# Processing Record 12 of Set 14 | upata
# Processing Record 13 of Set 14 | witu
# Processing Record 14 of Set 14 | sindgi
# Processing Record 15 of Set 14 | thongwa
# Processing Record 16 of Set 14 | san-pedro
# Processing Record 17 of Set 14 | eboli
# Processing Record 18 of Set 14 | bowling green
# Processing Record 19 of Set 14 | maniwaki
# Processing Record 20 of Set 14 | salaga
# Processing Record 21 of Set 14 | nacala
# Processing Record 22 of Set 14 | nurota
# Processing Record 23 of Set 14 | burgeo
# Processing Record 24 of Set 14 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 25 of Set 14 | urdzhar
# City not found. Skipping...
# Processing Record 26 of Set 14 | bur gabo
# City not found. Skipping...
# Processing Record 27 of Set 14 | portmore
# Processing Record 28 of Set 14 | pionerskiy
# Processing Record 29 of Set 14 | bendigo
# Processing Record 30 of Set 14 | danilovka
# Processing Record 31 of Set 14 | paamiut
# Processing Record 32 of Set 14 | carballo
# Processing Record 33 of Set 14 | lillehammer
# Processing Record 34 of Set 14 | mogadishu
# Processing Record 35 of Set 14 | khani
# Processing Record 36 of Set 14 | zachepylivka
# Processing Record 37 of Set 14 | martil
# Processing Record 38 of Set 14 | tiznit
# Processing Record 39 of Set 14 | souillac
# Processing Record 40 of Set 14 | rio brilhante
# Processing Record 41 of Set 14 | mapiripan
# Processing Record 42 of Set 14 | plouzane
# Processing Record 43 of Set 14 | chaman
# Processing Record 44 of Set 14 | port augusta
# Processing Record 45 of Set 14 | talnakh
# Processing Record 46 of Set 14 | baculin
# Processing Record 47 of Set 14 | la rochelle
# Processing Record 48 of Set 14 | roebourne
# Processing Record 49 of Set 14 | hofn
# Processing Record 50 of Set 14 | tura
# Processing Record 1 of Set 15 | lakota
# Processing Record 2 of Set 15 | nong kung si
# Processing Record 3 of Set 15 | sandwick
# Processing Record 4 of Set 15 | cantaura
# Processing Record 5 of Set 15 | iroquois falls
# Processing Record 6 of Set 15 | lewisporte
# Processing Record 7 of Set 15 | hay river
# Processing Record 8 of Set 15 | zlobin
# Processing Record 9 of Set 15 | iranshahr
# Processing Record 10 of Set 15 | hami
# Processing Record 11 of Set 15 | naze
# Processing Record 12 of Set 15 | dandong
# Processing Record 13 of Set 15 | babanusah
# City not found. Skipping...
# Processing Record 14 of Set 15 | deputatskiy
# Processing Record 15 of Set 15 | naraini
# Processing Record 16 of Set 15 | zhezkazgan
# Processing Record 17 of Set 15 | gushikawa
# Processing Record 18 of Set 15 | gravdal
# Processing Record 19 of Set 15 | russell
# Processing Record 20 of Set 15 | cambre
# Processing Record 21 of Set 15 | port-cartier
# Processing Record 22 of Set 15 | arrecife
# Processing Record 23 of Set 15 | pisco
# Processing Record 24 of Set 15 | nauta
# Processing Record 25 of Set 15 | norden
# Processing Record 26 of Set 15 | pachmarhi
# Processing Record 27 of Set 15 | carbondale
# Processing Record 28 of Set 15 | dicabisagan
# Processing Record 29 of Set 15 | fare
# Processing Record 30 of Set 15 | ayia galini
# Processing Record 31 of Set 15 | nogliki
# Processing Record 32 of Set 15 | adoni
# Processing Record 33 of Set 15 | gbadolite
# Processing Record 34 of Set 15 | severnoye
# Processing Record 35 of Set 15 | buchanan
# Processing Record 36 of Set 15 | visakhapatnam
# Processing Record 37 of Set 15 | gull lake
# Processing Record 38 of Set 15 | umea
# Processing Record 39 of Set 15 | moranbah
# Processing Record 40 of Set 15 | saint-augustin
# Processing Record 41 of Set 15 | celestun
# Processing Record 42 of Set 15 | tigil
# Processing Record 43 of Set 15 | middle island
# Processing Record 44 of Set 15 | ulaanbaatar
# Processing Record 45 of Set 15 | haibowan
# City not found. Skipping...
# Processing Record 46 of Set 15 | ostrogozhsk
# Processing Record 47 of Set 15 | vetluzhskiy
# Processing Record 48 of Set 15 | denpasar
# Processing Record 49 of Set 15 | hue
# Processing Record 50 of Set 15 | bonthe
# Processing Record 1 of Set 16 | gaoyou
# Processing Record 2 of Set 16 | xingyi
# Processing Record 3 of Set 16 | bluefields
# Processing Record 4 of Set 16 | djambala
# Processing Record 5 of Set 16 | hazorasp
# Processing Record 6 of Set 16 | woodland
# Processing Record 7 of Set 16 | portland
# Processing Record 8 of Set 16 | boskovice
# Processing Record 9 of Set 16 | lagos de moreno
# Processing Record 10 of Set 16 | tete
# Processing Record 11 of Set 16 | marsa matruh
# Processing Record 12 of Set 16 | karratha
# Processing Record 13 of Set 16 | kutum
# Processing Record 14 of Set 16 | camana
# Processing Record 15 of Set 16 | henties bay
# Processing Record 16 of Set 16 | billings
# Processing Record 17 of Set 16 | pacific grove
# Processing Record 18 of Set 16 | san ramon
# Processing Record 19 of Set 16 | boende
# Processing Record 20 of Set 16 | calama
# Processing Record 21 of Set 16 | burley
# Processing Record 22 of Set 16 | hirtshals
# Processing Record 23 of Set 16 | takoradi
# Processing Record 24 of Set 16 | cap malheureux
# Processing Record 25 of Set 16 | guerrero negro
# Processing Record 26 of Set 16 | urubicha
# Processing Record 27 of Set 16 | kachikau
# City not found. Skipping...
# Processing Record 28 of Set 16 | stantsionno-oyashinskiy
# Processing Record 29 of Set 16 | tonantins
# Processing Record 30 of Set 16 | black river
# Processing Record 31 of Set 16 | galesong
# Processing Record 32 of Set 16 | bara
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 725

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#               City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0        Busselton -33.65  115.33     48.99        86          39        9.28
# 1  Bambous Virieux -20.34   57.76     69.80        77          40        8.05
# 2   Port Elizabeth -33.92   25.57     57.20        93          40        4.70
# 3             Hilo  19.73 -155.09     86.00        66           1       10.29
# 4         Barcelos  41.54   -8.62     64.99        88           1        8.05
#
#   Country Current Description
# 0      AU    scattered clouds
# 1      MU    scattered clouds
# 2      ZA    scattered clouds
# 3      US           clear sky
# 4      PT           clear sky

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#               City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0        Busselton      AU -33.65  115.33     48.99        86          39
# 1  Bambous Virieux      MU -20.34   57.76     69.80        77          40
# 2   Port Elizabeth      ZA -33.92   25.57     57.20        93          40
# 3             Hilo      US  19.73 -155.09     86.00        66           1
# 4         Barcelos      PT  41.54   -8.62     64.99        88           1
# 5          Kamenka      RU  51.32   42.77     54.00        72          69
# 6        Maneadero      MX  31.72 -116.57     82.00        78           3
# 7    Wichita Falls      US  33.91  -98.49     95.00        28           1
# 8           Jilove      CZ  50.76   14.10     62.01        97          31
# 9     Christchurch      NZ -43.53  172.63     53.01       100         100
#
#    Wind Speed Current Description
# 0        9.28    scattered clouds
# 1        8.05    scattered clouds
# 2        4.70    scattered clouds
# 3       10.29           clear sky
# 4        8.05           clear sky
# 5        1.99       broken clouds
# 6        3.00          light rain
# 7        9.17           clear sky
# 8        4.27    scattered clouds
# 9        5.82             drizzle

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
