# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(-90.000, 90.000, size=2000)
lngs = np.random.uniform(-180.000, 180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
# coordinates

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 780

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
#url

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Begining of Data Retrivel")
print("-------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # print(city_weather)
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        # city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Begining of Data Retrivel
# -------------------------
# Processing Record 1 of Set 1 | concordia
# Processing Record 2 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 3 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 4 of Set 1 | arman
# Processing Record 5 of Set 1 | busselton
# Processing Record 6 of Set 1 | banjar
# Processing Record 7 of Set 1 | kirakira
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | artyom
# Processing Record 10 of Set 1 | san cristobal
# Processing Record 11 of Set 1 | oktyabrskoye
# Processing Record 12 of Set 1 | vila velha
# Processing Record 13 of Set 1 | nanortalik
# Processing Record 14 of Set 1 | oruro
# Processing Record 15 of Set 1 | albany
# Processing Record 16 of Set 1 | mahebourg
# Processing Record 17 of Set 1 | upernavik
# Processing Record 18 of Set 1 | esperance
# Processing Record 19 of Set 1 | victoria
# Processing Record 20 of Set 1 | arraial do cabo
# Processing Record 21 of Set 1 | namibe
# Processing Record 22 of Set 1 | constitucion
# Processing Record 23 of Set 1 | praia
# Processing Record 24 of Set 1 | khatanga
# Processing Record 25 of Set 1 | passo de camaragibe
# Processing Record 26 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 27 of Set 1 | hilo
# Processing Record 28 of Set 1 | portland
# Processing Record 29 of Set 1 | acushnet
# Processing Record 30 of Set 1 | bijawar
# Processing Record 31 of Set 1 | new norfolk
# Processing Record 32 of Set 1 | sur
# Processing Record 33 of Set 1 | rikitea
# Processing Record 34 of Set 1 | karrapur
# Processing Record 35 of Set 1 | atuona
# Processing Record 36 of Set 1 | adeje
# Processing Record 37 of Set 1 | santa rosa
# Processing Record 38 of Set 1 | mae sai
# Processing Record 39 of Set 1 | trinidad
# Processing Record 40 of Set 1 | hobart
# Processing Record 41 of Set 1 | largu
# Processing Record 42 of Set 1 | mataura
# Processing Record 43 of Set 1 | east london
# Processing Record 44 of Set 1 | sola
# Processing Record 45 of Set 1 | fortuna
# Processing Record 46 of Set 1 | malanje
# Processing Record 47 of Set 1 | vaini
# Processing Record 48 of Set 1 | tuktoyaktuk
# Processing Record 49 of Set 1 | deputatskiy
# Processing Record 50 of Set 1 | tomohon
# Processing Record 1 of Set 2 | ponta do sol
# Processing Record 2 of Set 2 | san quintin
# Processing Record 3 of Set 2 | sobolevo
# Processing Record 4 of Set 2 | grants
# Processing Record 5 of Set 2 | san carlos
# Processing Record 6 of Set 2 | male
# Processing Record 7 of Set 2 | khani
# Processing Record 8 of Set 2 | lebu
# Processing Record 9 of Set 2 | sonoita
# Processing Record 10 of Set 2 | chokurdakh
# Processing Record 11 of Set 2 | port blair
# Processing Record 12 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 2 | boulder city
# Processing Record 14 of Set 2 | pevek
# Processing Record 15 of Set 2 | piacabucu
# Processing Record 16 of Set 2 | toora-khem
# Processing Record 17 of Set 2 | torbay
# Processing Record 18 of Set 2 | puerto ayora
# Processing Record 19 of Set 2 | qaanaaq
# Processing Record 20 of Set 2 | truro
# Processing Record 21 of Set 2 | jamestown
# Processing Record 22 of Set 2 | hobyo
# Processing Record 23 of Set 2 | mandera
# Processing Record 24 of Set 2 | berlevag
# Processing Record 25 of Set 2 | maldonado
# Processing Record 26 of Set 2 | hami
# Processing Record 27 of Set 2 | luderitz
# Processing Record 28 of Set 2 | puerto suarez
# Processing Record 29 of Set 2 | chuy
# Processing Record 30 of Set 2 | dingle
# Processing Record 31 of Set 2 | saskylakh
# Processing Record 32 of Set 2 | mar del plata
# Processing Record 33 of Set 2 | severo-kurilsk
# Processing Record 34 of Set 2 | dakar
# Processing Record 35 of Set 2 | port alfred
# Processing Record 36 of Set 2 | noumea
# Processing Record 37 of Set 2 | castro
# Processing Record 38 of Set 2 | tucurui
# Processing Record 39 of Set 2 | provideniya
# Processing Record 40 of Set 2 | bredasdorp
# Processing Record 41 of Set 2 | butaritari
# Processing Record 42 of Set 2 | gurskoye
# City not found. Skipping...
# Processing Record 43 of Set 2 | kapaa
# Processing Record 44 of Set 2 | havoysund
# Processing Record 45 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 46 of Set 2 | balkhash
# Processing Record 47 of Set 2 | ahipara
# Processing Record 48 of Set 2 | port elizabeth
# Processing Record 49 of Set 2 | brae
# Processing Record 50 of Set 2 | urengoy
# Processing Record 1 of Set 3 | cape town
# Processing Record 2 of Set 3 | punta arenas
# Processing Record 3 of Set 3 | nome
# Processing Record 4 of Set 3 | georgetown
# Processing Record 5 of Set 3 | bilma
# Processing Record 6 of Set 3 | sainte-martine
# Processing Record 7 of Set 3 | antalaha
# Processing Record 8 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 9 of Set 3 | flinders
# Processing Record 10 of Set 3 | thompson
# Processing Record 11 of Set 3 | ifanadiana
# Processing Record 12 of Set 3 | xining
# Processing Record 13 of Set 3 | te anau
# Processing Record 14 of Set 3 | avarua
# Processing Record 15 of Set 3 | yeovil
# Processing Record 16 of Set 3 | ostrovnoy
# Processing Record 17 of Set 3 | flin flon
# Processing Record 18 of Set 3 | bethel
# Processing Record 19 of Set 3 | muros
# Processing Record 20 of Set 3 | bengkulu
# Processing Record 21 of Set 3 | alofi
# Processing Record 22 of Set 3 | batticaloa
# Processing Record 23 of Set 3 | yumen
# Processing Record 24 of Set 3 | effingham
# Processing Record 25 of Set 3 | saint george
# Processing Record 26 of Set 3 | nueva vida
# Processing Record 27 of Set 3 | russell
# Processing Record 28 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 29 of Set 3 | tamandare
# Processing Record 30 of Set 3 | finschhafen
# Processing Record 31 of Set 3 | hithadhoo
# Processing Record 32 of Set 3 | airai
# Processing Record 33 of Set 3 | waycross
# Processing Record 34 of Set 3 | longyearbyen
# Processing Record 35 of Set 3 | kalamare
# Processing Record 36 of Set 3 | nhulunbuy
# Processing Record 37 of Set 3 | torres
# Processing Record 38 of Set 3 | cherskiy
# Processing Record 39 of Set 3 | coquimbo
# Processing Record 40 of Set 3 | zhangye
# Processing Record 41 of Set 3 | broome
# Processing Record 42 of Set 3 | cheyur
# City not found. Skipping...
# Processing Record 43 of Set 3 | beringovskiy
# Processing Record 44 of Set 3 | ruteng
# Processing Record 45 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 46 of Set 3 | meadow lake
# Processing Record 47 of Set 3 | camana
# Processing Record 48 of Set 3 | vila franca do campo
# Processing Record 49 of Set 3 | artvin
# Processing Record 50 of Set 3 | sao gabriel da cachoeira
# Processing Record 1 of Set 4 | sao filipe
# Processing Record 2 of Set 4 | ronnenberg
# Processing Record 3 of Set 4 | carballo
# Processing Record 4 of Set 4 | carbonia
# Processing Record 5 of Set 4 | hermanus
# Processing Record 6 of Set 4 | quang ngai
# Processing Record 7 of Set 4 | manicore
# Processing Record 8 of Set 4 | cortez
# Processing Record 9 of Set 4 | dikson
# Processing Record 10 of Set 4 | leningradskiy
# Processing Record 11 of Set 4 | anadyr
# Processing Record 12 of Set 4 | imbituba
# Processing Record 13 of Set 4 | guerrero negro
# Processing Record 14 of Set 4 | sawtell
# Processing Record 15 of Set 4 | glenwood springs
# Processing Record 16 of Set 4 | moron
# Processing Record 17 of Set 4 | dudinka
# Processing Record 18 of Set 4 | novonukutskiy
# Processing Record 19 of Set 4 | port lincoln
# Processing Record 20 of Set 4 | neresnytsya
# Processing Record 21 of Set 4 | nikolskoye
# Processing Record 22 of Set 4 | bluff
# Processing Record 23 of Set 4 | dalbandin
# Processing Record 24 of Set 4 | faanui
# Processing Record 25 of Set 4 | taltal
# Processing Record 26 of Set 4 | ombessa
# Processing Record 27 of Set 4 | bautar
# Processing Record 28 of Set 4 | souillac
# Processing Record 29 of Set 4 | miyako
# Processing Record 30 of Set 4 | qeshm
# Processing Record 31 of Set 4 | bambous virieux
# Processing Record 32 of Set 4 | ust-charyshskaya pristan
# Processing Record 33 of Set 4 | forbes
# Processing Record 34 of Set 4 | ende
# Processing Record 35 of Set 4 | astoria
# Processing Record 36 of Set 4 | zhanaozen
# Processing Record 37 of Set 4 | erzin
# Processing Record 38 of Set 4 | havelock
# Processing Record 39 of Set 4 | fillan
# Processing Record 40 of Set 4 | anloga
# Processing Record 41 of Set 4 | verkhnevilyuysk
# Processing Record 42 of Set 4 | grand gaube
# Processing Record 43 of Set 4 | san jose
# Processing Record 44 of Set 4 | kaitangata
# Processing Record 45 of Set 4 | auki
# Processing Record 46 of Set 4 | hualmay
# Processing Record 47 of Set 4 | bilibino
# Processing Record 48 of Set 4 | monrovia
# Processing Record 49 of Set 4 | poum
# Processing Record 50 of Set 4 | vao
# Processing Record 1 of Set 5 | ilulissat
# Processing Record 2 of Set 5 | nanhai
# Processing Record 3 of Set 5 | paidha
# Processing Record 4 of Set 5 | richards bay
# Processing Record 5 of Set 5 | yellowknife
# Processing Record 6 of Set 5 | obluche
# City not found. Skipping...
# Processing Record 7 of Set 5 | bull savanna
# Processing Record 8 of Set 5 | livingston
# Processing Record 9 of Set 5 | am timan
# Processing Record 10 of Set 5 | naze
# Processing Record 11 of Set 5 | lagoa
# Processing Record 12 of Set 5 | hirara
# Processing Record 13 of Set 5 | barrow
# Processing Record 14 of Set 5 | dourbali
# Processing Record 15 of Set 5 | ajdabiya
# Processing Record 16 of Set 5 | port hardy
# Processing Record 17 of Set 5 | mogocha
# Processing Record 18 of Set 5 | geraldton
# Processing Record 19 of Set 5 | karratha
# Processing Record 20 of Set 5 | ribeira grande
# Processing Record 21 of Set 5 | kawalu
# Processing Record 22 of Set 5 | ryde
# Processing Record 23 of Set 5 | talnakh
# Processing Record 24 of Set 5 | turkmenabat
# Processing Record 25 of Set 5 | vostok
# Processing Record 26 of Set 5 | kruisfontein
# Processing Record 27 of Set 5 | texarkana
# Processing Record 28 of Set 5 | meulaboh
# Processing Record 29 of Set 5 | binga
# Processing Record 30 of Set 5 | road town
# Processing Record 31 of Set 5 | tiruvottiyur
# City not found. Skipping...
# Processing Record 32 of Set 5 | husavik
# Processing Record 33 of Set 5 | san andres
# Processing Record 34 of Set 5 | naro moru
# Processing Record 35 of Set 5 | mairana
# Processing Record 36 of Set 5 | orlik
# Processing Record 37 of Set 5 | ancud
# Processing Record 38 of Set 5 | veraval
# Processing Record 39 of Set 5 | mount gambier
# Processing Record 40 of Set 5 | la argentina
# Processing Record 41 of Set 5 | itanhaem
# Processing Record 42 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 43 of Set 5 | inhambane
# Processing Record 44 of Set 5 | qurbus
# Processing Record 45 of Set 5 | luganville
# Processing Record 46 of Set 5 | lasa
# Processing Record 47 of Set 5 | broken hill
# Processing Record 48 of Set 5 | chumikan
# Processing Record 49 of Set 5 | sao joao da barra
# Processing Record 50 of Set 5 | lorengau
# Processing Record 1 of Set 6 | gat
# Processing Record 2 of Set 6 | chillicothe
# Processing Record 3 of Set 6 | asau
# Processing Record 4 of Set 6 | yafran
# Processing Record 5 of Set 6 | kahului
# Processing Record 6 of Set 6 | siocon
# Processing Record 7 of Set 6 | edd
# Processing Record 8 of Set 6 | neiafu
# Processing Record 9 of Set 6 | bossier city
# Processing Record 10 of Set 6 | okha
# Processing Record 11 of Set 6 | roald
# Processing Record 12 of Set 6 | barbar
# City not found. Skipping...
# Processing Record 13 of Set 6 | greenville
# Processing Record 14 of Set 6 | mayo
# Processing Record 15 of Set 6 | port-gentil
# Processing Record 16 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 17 of Set 6 | faya
# Processing Record 18 of Set 6 | yunjinghong
# City not found. Skipping...
# Processing Record 19 of Set 6 | tasiilaq
# Processing Record 20 of Set 6 | port hedland
# Processing Record 21 of Set 6 | kamenka
# Processing Record 22 of Set 6 | calbuco
# Processing Record 23 of Set 6 | los palacios
# Processing Record 24 of Set 6 | margate
# Processing Record 25 of Set 6 | dori
# Processing Record 26 of Set 6 | cayenne
# Processing Record 27 of Set 6 | vallenar
# Processing Record 28 of Set 6 | tessalit
# Processing Record 29 of Set 6 | bijie
# Processing Record 30 of Set 6 | westport
# Processing Record 31 of Set 6 | lensk
# Processing Record 32 of Set 6 | goma
# Processing Record 33 of Set 6 | northam
# Processing Record 34 of Set 6 | lewisporte
# Processing Record 35 of Set 6 | carnarvon
# Processing Record 36 of Set 6 | general pico
# Processing Record 37 of Set 6 | lompoc
# Processing Record 38 of Set 6 | loubomo
# Processing Record 39 of Set 6 | verkhniy baskunchak
# Processing Record 40 of Set 6 | saint-joseph
# Processing Record 41 of Set 6 | banda aceh
# Processing Record 42 of Set 6 | sampit
# Processing Record 43 of Set 6 | roebourne
# Processing Record 44 of Set 6 | dembi dolo
# Processing Record 45 of Set 6 | honningsvag
# Processing Record 46 of Set 6 | mandan
# Processing Record 47 of Set 6 | beberibe
# Processing Record 48 of Set 6 | san patricio
# Processing Record 49 of Set 6 | promyshlennyy
# Processing Record 50 of Set 6 | clyde river
# Processing Record 1 of Set 7 | artyk
# City not found. Skipping...
# Processing Record 2 of Set 7 | el alto
# Processing Record 3 of Set 7 | liuhe
# Processing Record 4 of Set 7 | nantucket
# Processing Record 5 of Set 7 | mananjary
# Processing Record 6 of Set 7 | nova vicosa
# Processing Record 7 of Set 7 | lahij
# Processing Record 8 of Set 7 | teguise
# Processing Record 9 of Set 7 | uttaradit
# Processing Record 10 of Set 7 | narsaq
# Processing Record 11 of Set 7 | phuket
# Processing Record 12 of Set 7 | altamira
# Processing Record 13 of Set 7 | le port
# Processing Record 14 of Set 7 | crotone
# Processing Record 15 of Set 7 | sakakah
# Processing Record 16 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 17 of Set 7 | los llanos de aridane
# Processing Record 18 of Set 7 | kununurra
# Processing Record 19 of Set 7 | saint-philippe
# Processing Record 20 of Set 7 | newport
# Processing Record 21 of Set 7 | wulanhaote
# City not found. Skipping...
# Processing Record 22 of Set 7 | bubaque
# Processing Record 23 of Set 7 | maniitsoq
# Processing Record 24 of Set 7 | aksay
# Processing Record 25 of Set 7 | saint-pierre
# Processing Record 26 of Set 7 | jalingo
# Processing Record 27 of Set 7 | winnemucca
# Processing Record 28 of Set 7 | mareeba
# Processing Record 29 of Set 7 | grindavik
# Processing Record 30 of Set 7 | cabedelo
# Processing Record 31 of Set 7 | isangel
# Processing Record 32 of Set 7 | machiques
# Processing Record 33 of Set 7 | caraquet
# Processing Record 34 of Set 7 | kalmunai
# Processing Record 35 of Set 7 | half moon bay
# Processing Record 36 of Set 7 | alexandria
# Processing Record 37 of Set 7 | elat
# Processing Record 38 of Set 7 | vigrestad
# Processing Record 39 of Set 7 | amecac
# City not found. Skipping...
# Processing Record 40 of Set 7 | saryshagan
# City not found. Skipping...
# Processing Record 41 of Set 7 | saldanha
# Processing Record 42 of Set 7 | dhidhdhoo
# Processing Record 43 of Set 7 | tura
# Processing Record 44 of Set 7 | cidreira
# Processing Record 45 of Set 7 | sao francisco de paula
# Processing Record 46 of Set 7 | sungaipenuh
# Processing Record 47 of Set 7 | penzance
# Processing Record 48 of Set 7 | jiaocheng
# Processing Record 49 of Set 7 | egvekinot
# Processing Record 50 of Set 7 | shalakusha
# Processing Record 1 of Set 8 | mana
# Processing Record 2 of Set 8 | hanzhong
# Processing Record 3 of Set 8 | ranong
# Processing Record 4 of Set 8 | katsuura
# Processing Record 5 of Set 8 | machhiwara
# Processing Record 6 of Set 8 | remedios
# Processing Record 7 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 8 of Set 8 | pacific grove
# Processing Record 9 of Set 8 | karasjok
# Processing Record 10 of Set 8 | caravelas
# Processing Record 11 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 12 of Set 8 | kara
# Processing Record 13 of Set 8 | poopo
# Processing Record 14 of Set 8 | sharjah
# Processing Record 15 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 16 of Set 8 | mackay
# Processing Record 17 of Set 8 | usvyaty
# Processing Record 18 of Set 8 | dukat
# Processing Record 19 of Set 8 | kavieng
# Processing Record 20 of Set 8 | pozo colorado
# Processing Record 21 of Set 8 | salalah
# Processing Record 22 of Set 8 | gushikawa
# Processing Record 23 of Set 8 | hamilton
# Processing Record 24 of Set 8 | elko
# Processing Record 25 of Set 8 | darhan
# Processing Record 26 of Set 8 | zhezkazgan
# Processing Record 27 of Set 8 | parker
# Processing Record 28 of Set 8 | acapulco
# Processing Record 29 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 30 of Set 8 | north bend
# Processing Record 31 of Set 8 | viedma
# Processing Record 32 of Set 8 | emba
# Processing Record 33 of Set 8 | tommot
# Processing Record 34 of Set 8 | blyznyuky
# Processing Record 35 of Set 8 | matagami
# Processing Record 36 of Set 8 | synya
# Processing Record 37 of Set 8 | vila
# Processing Record 38 of Set 8 | hohhot
# Processing Record 39 of Set 8 | uyovu
# Processing Record 40 of Set 8 | sisimiut
# Processing Record 41 of Set 8 | fershampenuaz
# Processing Record 42 of Set 8 | kodiak
# Processing Record 43 of Set 8 | ossora
# Processing Record 44 of Set 8 | moa
# Processing Record 45 of Set 8 | severo-yeniseyskiy
# Processing Record 46 of Set 8 | codrington
# Processing Record 47 of Set 8 | eyl
# Processing Record 48 of Set 8 | wagar
# Processing Record 49 of Set 8 | norman wells
# Processing Record 50 of Set 8 | chengde
# Processing Record 1 of Set 9 | corinth
# Processing Record 2 of Set 9 | aitape
# Processing Record 3 of Set 9 | payakumbuh
# Processing Record 4 of Set 9 | tiksi
# Processing Record 5 of Set 9 | balsas
# Processing Record 6 of Set 9 | calderitas
# Processing Record 7 of Set 9 | gladstone
# Processing Record 8 of Set 9 | madera
# Processing Record 9 of Set 9 | morondava
# Processing Record 10 of Set 9 | lucapa
# Processing Record 11 of Set 9 | palmer
# Processing Record 12 of Set 9 | fort nelson
# Processing Record 13 of Set 9 | adrar
# Processing Record 14 of Set 9 | merauke
# Processing Record 15 of Set 9 | rio gallegos
# Processing Record 16 of Set 9 | quatre cocos
# Processing Record 17 of Set 9 | kresttsy
# Processing Record 18 of Set 9 | liverpool
# Processing Record 19 of Set 9 | wairoa
# Processing Record 20 of Set 9 | key west
# Processing Record 21 of Set 9 | dehui
# Processing Record 22 of Set 9 | lebane
# Processing Record 23 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 24 of Set 9 | bathsheba
# Processing Record 25 of Set 9 | tuy hoa
# Processing Record 26 of Set 9 | barawe
# City not found. Skipping...
# Processing Record 27 of Set 9 | tuatapere
# Processing Record 28 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 29 of Set 9 | nimaparha
# Processing Record 30 of Set 9 | shenjiamen
# Processing Record 31 of Set 9 | zhumadian
# Processing Record 32 of Set 9 | dalianwan
# Processing Record 33 of Set 9 | alugan
# Processing Record 34 of Set 9 | myatlevo
# Processing Record 35 of Set 9 | leh
# Processing Record 36 of Set 9 | mantua
# Processing Record 37 of Set 9 | iqaluit
# Processing Record 38 of Set 9 | nyurba
# Processing Record 39 of Set 9 | kutum
# Processing Record 40 of Set 9 | sioux lookout
# Processing Record 41 of Set 9 | mitu
# Processing Record 42 of Set 9 | zhigansk
# Processing Record 43 of Set 9 | muli
# Processing Record 44 of Set 9 | surt
# Processing Record 45 of Set 9 | cajamarca
# Processing Record 46 of Set 9 | kurchum
# Processing Record 47 of Set 9 | karawang
# Processing Record 48 of Set 9 | pontiac
# Processing Record 49 of Set 9 | camacha
# Processing Record 50 of Set 9 | aklavik
# Processing Record 1 of Set 10 | laguna
# Processing Record 2 of Set 10 | talaja
# Processing Record 3 of Set 10 | kambove
# Processing Record 4 of Set 10 | dunedin
# Processing Record 5 of Set 10 | xihe
# Processing Record 6 of Set 10 | mikhaylovka
# Processing Record 7 of Set 10 | olafsvik
# Processing Record 8 of Set 10 | tazovskiy
# Processing Record 9 of Set 10 | warrnambool
# Processing Record 10 of Set 10 | harnosand
# Processing Record 11 of Set 10 | rawson
# Processing Record 12 of Set 10 | hofn
# Processing Record 13 of Set 10 | acurenam
# Processing Record 14 of Set 10 | aksarka
# Processing Record 15 of Set 10 | korla
# Processing Record 16 of Set 10 | alta floresta
# Processing Record 17 of Set 10 | winneba
# Processing Record 18 of Set 10 | goderich
# Processing Record 19 of Set 10 | sitka
# Processing Record 20 of Set 10 | hunza
# City not found. Skipping...
# Processing Record 21 of Set 10 | willowmore
# Processing Record 22 of Set 10 | san-pedro
# Processing Record 23 of Set 10 | mombetsu
# Processing Record 24 of Set 10 | aktyubinskiy
# Processing Record 25 of Set 10 | kolondieba
# Processing Record 26 of Set 10 | warri
# Processing Record 27 of Set 10 | syumsi
# Processing Record 28 of Set 10 | sijunjung
# Processing Record 29 of Set 10 | szentgotthard
# Processing Record 30 of Set 10 | port augusta
# Processing Record 31 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 32 of Set 10 | jumla
# Processing Record 33 of Set 10 | balyaga
# Processing Record 34 of Set 10 | klaksvik
# Processing Record 35 of Set 10 | sungairaya
# Processing Record 36 of Set 10 | dolinsk
# Processing Record 37 of Set 10 | amapa
# Processing Record 38 of Set 10 | kharp
# Processing Record 39 of Set 10 | salinas
# Processing Record 40 of Set 10 | kattivakkam
# Processing Record 41 of Set 10 | wanning
# Processing Record 42 of Set 10 | andradas
# Processing Record 43 of Set 10 | atambua
# Processing Record 44 of Set 10 | ormara
# Processing Record 45 of Set 10 | alashtar
# City not found. Skipping...
# Processing Record 46 of Set 10 | chama
# Processing Record 47 of Set 10 | ilongero
# Processing Record 48 of Set 10 | sivaki
# Processing Record 49 of Set 10 | labutta
# City not found. Skipping...
# Processing Record 50 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 1 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 2 of Set 11 | chiredzi
# Processing Record 3 of Set 11 | zabaykalsk
# Processing Record 4 of Set 11 | buraydah
# Processing Record 5 of Set 11 | parabel
# Processing Record 6 of Set 11 | vanimo
# Processing Record 7 of Set 11 | makat
# Processing Record 8 of Set 11 | oytal
# Processing Record 9 of Set 11 | waingapu
# Processing Record 10 of Set 11 | ballina
# Processing Record 11 of Set 11 | honiara
# Processing Record 12 of Set 11 | rafaela
# Processing Record 13 of Set 11 | lahad datu
# Processing Record 14 of Set 11 | denpasar
# Processing Record 15 of Set 11 | kloulklubed
# Processing Record 16 of Set 11 | zhanakorgan
# Processing Record 17 of Set 11 | cabo san lucas
# Processing Record 18 of Set 11 | hammerfest
# Processing Record 19 of Set 11 | ciudad bolivar
# Processing Record 20 of Set 11 | samarai
# Processing Record 21 of Set 11 | bonthe
# Processing Record 22 of Set 11 | mumford
# Processing Record 23 of Set 11 | hauterive
# Processing Record 24 of Set 11 | nelson bay
# Processing Record 25 of Set 11 | chabahar
# Processing Record 26 of Set 11 | zhuhai
# Processing Record 27 of Set 11 | oranjestad
# Processing Record 28 of Set 11 | shimoda
# Processing Record 29 of Set 11 | wonthaggi
# Processing Record 30 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 31 of Set 11 | kashi
# Processing Record 32 of Set 11 | maragogi
# Processing Record 33 of Set 11 | bagan
# Processing Record 34 of Set 11 | pangnirtung
# Processing Record 35 of Set 11 | kyshtovka
# Processing Record 36 of Set 11 | ures
# Processing Record 37 of Set 11 | santo tomas
# Processing Record 38 of Set 11 | mount isa
# Processing Record 39 of Set 11 | port victoria
# Processing Record 40 of Set 11 | sumbe
# Processing Record 41 of Set 11 | kieta
# Processing Record 42 of Set 11 | tabaquite
# Processing Record 43 of Set 11 | tautira
# Processing Record 44 of Set 11 | ko samui
# Processing Record 45 of Set 11 | pechenga
# Processing Record 46 of Set 11 | susanville
# Processing Record 47 of Set 11 | grand island
# Processing Record 48 of Set 11 | manuk mangkaw
# Processing Record 49 of Set 11 | tahta
# Processing Record 50 of Set 11 | tondano
# Processing Record 1 of Set 12 | tongchuan
# Processing Record 2 of Set 12 | tekax
# City not found. Skipping...
# Processing Record 3 of Set 12 | sorland
# Processing Record 4 of Set 12 | alberdi
# Processing Record 5 of Set 12 | pombas
# Processing Record 6 of Set 12 | korgen
# Processing Record 7 of Set 12 | buan
# Processing Record 8 of Set 12 | safranbolu
# Processing Record 9 of Set 12 | loa janan
# Processing Record 10 of Set 12 | taseyevo
# Processing Record 11 of Set 12 | savannah bight
# Processing Record 12 of Set 12 | fort saint john
# City not found. Skipping...
# Processing Record 13 of Set 12 | suntar
# Processing Record 14 of Set 12 | hargeysa
# Processing Record 15 of Set 12 | bardiyah
# Processing Record 16 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 17 of Set 12 | hua hin
# Processing Record 18 of Set 12 | sechenovo
# Processing Record 19 of Set 12 | udachnyy
# Processing Record 20 of Set 12 | aswan
# Processing Record 21 of Set 12 | kalaiya
# Processing Record 22 of Set 12 | lukh
# Processing Record 23 of Set 12 | saquarema
# Processing Record 24 of Set 12 | huarmey
# Processing Record 25 of Set 12 | kuandian
# Processing Record 26 of Set 12 | jalu
# Processing Record 27 of Set 12 | grand river south east
# City not found. Skipping...
# Processing Record 28 of Set 12 | skjervoy
# Processing Record 29 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 30 of Set 12 | baglung
# Processing Record 31 of Set 12 | george town
# Processing Record 32 of Set 12 | kamaishi
# Processing Record 33 of Set 12 | yar-sale
# Processing Record 34 of Set 12 | vanersborg
# Processing Record 35 of Set 12 | buzmeyin
# Processing Record 36 of Set 12 | sorong
# Processing Record 37 of Set 12 | mount darwin
# Processing Record 38 of Set 12 | shakawe
# Processing Record 39 of Set 12 | tevriz
# Processing Record 40 of Set 12 | cambridge
# Processing Record 41 of Set 12 | rangpo
# Processing Record 42 of Set 12 | kiama
# Processing Record 43 of Set 12 | kajaani
# Processing Record 44 of Set 12 | mersing
# Processing Record 45 of Set 12 | komsomolskiy
# Processing Record 46 of Set 12 | raha
# Processing Record 47 of Set 12 | lisakovsk
# Processing Record 48 of Set 12 | cam ranh
# Processing Record 49 of Set 12 | winfield
# Processing Record 50 of Set 12 | pacasmayo
# Processing Record 1 of Set 13 | gemena
# Processing Record 2 of Set 13 | burgeo
# Processing Record 3 of Set 13 | lephepe
# City not found. Skipping...
# Processing Record 4 of Set 13 | prince rupert
# Processing Record 5 of Set 13 | marsh harbour
# Processing Record 6 of Set 13 | champerico
# Processing Record 7 of Set 13 | kenora
# Processing Record 8 of Set 13 | sao felix do xingu
# Processing Record 9 of Set 13 | college
# Processing Record 10 of Set 13 | chino valley
# Processing Record 11 of Set 13 | ankang
# Processing Record 12 of Set 13 | mezhdurechensk
# Processing Record 13 of Set 13 | sahuaripa
# Processing Record 14 of Set 13 | hambantota
# Processing Record 15 of Set 13 | sao lourenco da serra
# Processing Record 16 of Set 13 | biak
# Processing Record 17 of Set 13 | rajanpur
# Processing Record 18 of Set 13 | mazatlan
# Processing Record 19 of Set 13 | banyo
# Processing Record 20 of Set 13 | icod de los vinos
# Processing Record 21 of Set 13 | iwanai
# Processing Record 22 of Set 13 | galeana
# Processing Record 23 of Set 13 | patacamaya
# Processing Record 24 of Set 13 | mlonggo
# Processing Record 25 of Set 13 | sakaraha
# Processing Record 26 of Set 13 | toliary
# City not found. Skipping...
# Processing Record 27 of Set 13 | labuhan
# Processing Record 28 of Set 13 | scarborough
# Processing Record 29 of Set 13 | tehachapi
# Processing Record 30 of Set 13 | boguchany
# Processing Record 31 of Set 13 | padang
# Processing Record 32 of Set 13 | arti
# Processing Record 33 of Set 13 | xuddur
# Processing Record 34 of Set 13 | cururupu
# Processing Record 35 of Set 13 | sierpc
# Processing Record 36 of Set 13 | san isidro
# Processing Record 37 of Set 13 | srednekolymsk
# Processing Record 38 of Set 13 | attawapiskat
# City not found. Skipping...
# Processing Record 39 of Set 13 | aksu
# Processing Record 40 of Set 13 | bodden town
# Processing Record 41 of Set 13 | karaton
# Processing Record 42 of Set 13 | alotau
# City not found. Skipping...
# Processing Record 43 of Set 13 | lata
# Processing Record 44 of Set 13 | green river
# Processing Record 45 of Set 13 | hihifo
# City not found. Skipping...
# Processing Record 46 of Set 13 | fukuma
# Processing Record 47 of Set 13 | coihaique
# Processing Record 48 of Set 13 | pabrade
# Processing Record 49 of Set 13 | rabo de peixe
# Processing Record 50 of Set 13 | sao jose da coroa grande
# Processing Record 1 of Set 14 | menongue
# Processing Record 2 of Set 14 | namatanai
# Processing Record 3 of Set 14 | bamiantong
# Processing Record 4 of Set 14 | santa cruz
# Processing Record 5 of Set 14 | baykit
# Processing Record 6 of Set 14 | amarante do maranhao
# Processing Record 7 of Set 14 | petropavl
# Processing Record 8 of Set 14 | itapecerica
# Processing Record 9 of Set 14 | manavalakurichi
# Processing Record 10 of Set 14 | macas
# Processing Record 11 of Set 14 | shakiso
# Processing Record 12 of Set 14 | tual
# Processing Record 13 of Set 14 | filingue
# Processing Record 14 of Set 14 | karakendzha
# City not found. Skipping...
# Processing Record 15 of Set 14 | karasburg
# Processing Record 16 of Set 14 | khorixas
# Processing Record 17 of Set 14 | rohri
# Processing Record 18 of Set 14 | odweyne
# Processing Record 19 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 20 of Set 14 | buala
# Processing Record 21 of Set 14 | solnechnyy
# Processing Record 22 of Set 14 | khagrachari
# City not found. Skipping...
# Processing Record 23 of Set 14 | tabou
# Processing Record 24 of Set 14 | yanam
# Processing Record 25 of Set 14 | skelleftea
# Processing Record 26 of Set 14 | nkwerre
# Processing Record 27 of Set 14 | palu
# Processing Record 28 of Set 14 | dharmanagar
# Processing Record 29 of Set 14 | kamina
# Processing Record 30 of Set 14 | turukhansk
# Processing Record 31 of Set 14 | suileng
# Processing Record 32 of Set 14 | tsienyane
# City not found. Skipping...
# Processing Record 33 of Set 14 | fos-sur-mer
# Processing Record 34 of Set 14 | patna
# Processing Record 35 of Set 14 | ucluelet
# Processing Record 36 of Set 14 | hasaki
# Processing Record 37 of Set 14 | urumqi
# Processing Record 38 of Set 14 | taoudenni
# Processing Record 39 of Set 14 | potam
# Processing Record 40 of Set 14 | portaria
# Processing Record 41 of Set 14 | ponta delgada
# Processing Record 42 of Set 14 | wilmington island
# Processing Record 43 of Set 14 | ngunguru
# Processing Record 44 of Set 14 | geresk
# City not found. Skipping...
# Processing Record 45 of Set 14 | marrakesh
# Processing Record 46 of Set 14 | broomfield
# Processing Record 47 of Set 14 | matto
# City not found. Skipping...
# Processing Record 48 of Set 14 | escada
# Processing Record 49 of Set 14 | nebug
# Processing Record 50 of Set 14 | hay river
# Processing Record 1 of Set 15 | qasigiannguit
# Processing Record 2 of Set 15 | markala
# Processing Record 3 of Set 15 | sao paulo de olivenca
# Processing Record 4 of Set 15 | nuuk
# Processing Record 5 of Set 15 | quartucciu
# Processing Record 6 of Set 15 | eenhana
# Processing Record 7 of Set 15 | homer
# Processing Record 8 of Set 15 | gambo
# Processing Record 9 of Set 15 | grevesmuhlen
# Processing Record 10 of Set 15 | krasnyy yar
# Processing Record 11 of Set 15 | sombrio
# Processing Record 12 of Set 15 | kamen-rybolov
# Processing Record 13 of Set 15 | bredy
# Processing Record 14 of Set 15 | kwinana
# Processing Record 15 of Set 15 | ogdensburg
# Processing Record 16 of Set 15 | nuevo progreso
# Processing Record 17 of Set 15 | charters towers
# Processing Record 18 of Set 15 | alakurtti
# Processing Record 19 of Set 15 | abu dhabi
# Processing Record 20 of Set 15 | pundaguitan
# Processing Record 21 of Set 15 | beyneu
# Processing Record 22 of Set 15 | sangar
# Processing Record 23 of Set 15 | porto belo
# Processing Record 24 of Set 15 | la ronge
# Processing Record 25 of Set 15 | jingdezhen
# Processing Record 26 of Set 15 | rocha
# Processing Record 27 of Set 15 | atikokan
# Processing Record 28 of Set 15 | yulara
# Processing Record 29 of Set 15 | jinchang
# Processing Record 30 of Set 15 | inuvik
# Processing Record 31 of Set 15 | aragarcas
# Processing Record 32 of Set 15 | shubarkuduk
# Processing Record 33 of Set 15 | baruun-urt
# Processing Record 34 of Set 15 | katsina
# Processing Record 35 of Set 15 | kautokeino
# Processing Record 36 of Set 15 | timra
# Processing Record 37 of Set 15 | umm lajj
# Processing Record 38 of Set 15 | lincoln
# Processing Record 39 of Set 15 | mogadishu
# Processing Record 40 of Set 15 | port said
# Processing Record 41 of Set 15 | buchanan
# Processing Record 42 of Set 15 | kem
# Processing Record 43 of Set 15 | zyryanka
# Processing Record 44 of Set 15 | kamenskoye
# City not found. Skipping...
# Processing Record 45 of Set 15 | bongandanga
# Processing Record 46 of Set 15 | soledade
# Processing Record 47 of Set 15 | mugumu
# Processing Record 48 of Set 15 | boende
# Processing Record 49 of Set 15 | sayyan
# Processing Record 50 of Set 15 | dubbo
# Processing Record 1 of Set 16 | pobe
# Processing Record 2 of Set 16 | paamiut
# Processing Record 3 of Set 16 | ubud
# Processing Record 4 of Set 16 | coahuayana
# Processing Record 5 of Set 16 | ibra
# Processing Record 6 of Set 16 | mahuva
# Processing Record 7 of Set 16 | marsa matruh
# Processing Record 8 of Set 16 | fraserburgh
# Processing Record 9 of Set 16 | yashkul
# Processing Record 10 of Set 16 | rolim de moura
# City not found. Skipping...
# Processing Record 11 of Set 16 | tabuk
# Processing Record 12 of Set 16 | anaconda
# Processing Record 13 of Set 16 | san lorenzo
# Processing Record 14 of Set 16 | fairbanks
# Processing Record 15 of Set 16 | bose
# Processing Record 16 of Set 16 | pisco
# Processing Record 17 of Set 16 | pangkalanbuun
# Processing Record 18 of Set 16 | portoferraio
# Processing Record 19 of Set 16 | grand baie
# Processing Record 20 of Set 16 | cuautepec
# Processing Record 21 of Set 16 | samandag
# Processing Record 22 of Set 16 | kvarkeno
# Processing Record 23 of Set 16 | carutapera
# Processing Record 24 of Set 16 | calvinia
# Processing Record 25 of Set 16 | sept-iles
# Processing Record 26 of Set 16 | touros
# Processing Record 27 of Set 16 | tomatlan
# Processing Record 28 of Set 16 | morros
# Processing Record 29 of Set 16 | arlit
# Processing Record 30 of Set 16 | gilgit
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 728

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#         City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Concordia -31.39  -58.02     37.00        82           0        4.92
# 1      Arman  59.70  150.17     55.71        46          92       13.60
# 2  Busselton -33.65  115.33     66.99        49          95       12.12
# 3     Banjar  -8.19  114.97     84.20        89          40       16.11
# 4   Kirakira -10.45  161.92     84.49        75          91       10.67
#
#   Country Current Description
# 0      AR           clear sky
# 1      RU     overcast clouds
# 2      AU     overcast clouds
# 3      ID    scattered clouds
# 4      SB          light rain

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#             City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0      Concordia      AR -31.39  -58.02     37.00        82           0
# 1          Arman      RU  59.70  150.17     55.71        46          92
# 2      Busselton      AU -33.65  115.33     66.99        49          95
# 3         Banjar      ID  -8.19  114.97     84.20        89          40
# 4       Kirakira      SB -10.45  161.92     84.49        75          91
# 5        Ushuaia      AR -54.80  -68.30     39.20        86          75
# 6         Artyom      AZ  40.47   50.33     75.20        73          20
# 7  San Cristobal      VE   7.77  -72.22     67.28        92         100
# 8   Oktyabrskoye      RU  43.06   44.74     60.80        93          90
# 9     Vila Velha      BR -20.33  -40.29     68.00        72          75
#
#    Wind Speed          Current Description
# 0        4.92                    clear sky
# 1       13.60              overcast clouds
# 2       12.12              overcast clouds
# 3       16.11             scattered clouds
# 4       10.67                   light rain
# 5        6.93      light intensity drizzle
# 6       29.97                   few clouds
# 7        1.86                moderate rain
# 8        4.47  light intensity shower rain
# 9       11.41                broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
